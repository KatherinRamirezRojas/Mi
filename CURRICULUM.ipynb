# %% [markdown]
# <a href="https://colab.research.google.com/github/KatherinRamirezRojas/Mi/blob/main/CURRICULUM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CVLAC
# ## Mi currículum

# %% [markdown]
# <span style="color:green"> Katherin Ramirez Rojas </span>

# %% [markdown]
# ![foto.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# Profesional responsable, proactiva y dinámica, con pasión innata por alcanzar
# metas y superar desafíos, en búsqueda constante de superación y capacidad de
# aprender rápidamente, permitiendo enfrentar diversas situaciones con entusiasmo
# y confianza.
#
# Desarrollando habilidades para impartir clases en los diferentes niveles;
# universitaria, escuela superior y elemental, demostrando destrezas para abordar
# desafíos con creatividad y resolución.
#
# Predisposición para trabajar individualmente y en equipo, logrando destacar
# autonomía y disciplina para llevar a cabo proyectos de manera eficiente y
# contribuir positivamente al éxito conjunto de cualquier proyecto.
#
# Con gran expectativa espero formar parte de su equipo, aportando mi experiencia y
# pasión para alcanzar las metas establecidas.

# %% [markdown]
# **Mi primer código en Colab**

# %% [markdown]
# El área del triángulo es base por altura divido entre dos.
#
# $$ A=\frac{ab}{2}$$ donde $a,b \geq0$

# %%
a=float(input("por favor ingresa el valor de a :"))
b=float(input("por favor ingresa el valor de b :"))
A=(a*b)/2
print("El área del triangulo es ", A)
# Out:
# por favor ingresa el valor de a :3.5
# por favor ingresa el valor de b :3.9
# El área del triangulo es  6.825
